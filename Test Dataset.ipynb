# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# ### Commuter's Gender & Age

# %%
g = ['Male', 'Female']
gender = np.random.choice(g, size=200, p=(0.489, 0.511))

age = np.random.randint(low=18, high=65, size=200)

# %% [markdown]
# ### Commuter's Mode of Travel

# %%
# list of modes of travel.
m = ['private vehicle', 'public transport', 'cycle', 'walk']

# percentage split between modes of travel - 'private vehicle', 'public transport', 'cycle', 'walk'.
percentage = [0.62, 0.09, 0.11, 0.18]

# Generate 100 random data points for the different modes of travel, probability as per percentage split.
mode = np.random.choice(m, size=200, p=(percentage))

# Change NumPy Array to List to allow for counting of random modes of travel generated.
mode_list = mode.tolist()

# Count number of commuters using each mode of travel.
drivers = mode_list.count('private vehicle')
passengers = mode_list.count('public transport')
cyclists = mode_list.count('cycle')
walkers = mode_list.count('walk')

# Output count list as 'c'.
c = [drivers] + [passengers] + [cyclists] + [walkers]

print(c)

# Pie chart of percentage split between modes of travel.    
plt.pie(percentage, labels=m, explode = (0.1, 0.1, 0.1, 0.1), shadow=True, autopct='%1.1f%%')
plt.title("Modes of Travel - Percentage Split")
plt.show()

# Pie chart of randomly generated split between modes of travel. 
plt.pie(c, labels=m, explode = (0.1, 0.1, 0.1, 0.1), shadow=True, autopct='%1.1f%%')
plt.title("Modes of Travel - Randomly Generated")
plt.show()
# Out:
# [124, 18, 24, 34]

# %% [markdown]
# ### Commuter's Mode of Travel - Adjusted for Age Groups

# %%
def mot(age_list):
    '''Function to determine mode of 
    transport based on age group'''
    
    m = ['private vehicle', 'public transport', 'cycle', 'walk']
    mode = []

# percentage split between modes of travel - 'private vehicle', 'public transport', 'cycle', 'walk'.
# probabilities adjusted per age group.

    for val in age_list:
        
        if val in range(18, 25):
            w = np.random.choice(m, p=[0.40, 0.18, 0.20, 0.22])
            mode.append(w)
            
        elif val in range(25, 45):
            x = np.random.choice(m, p=[0.77, 0.11, 0.07, 0.05])
            mode.append(x)
            
        elif val in range(45, 60):
            y = np.random.choice(m, p=[0.82, 0.09, 0.04, 0.05])
            mode.append(y)

        else:
            z = np.random.choice(m, p=[0.65, 0.12, 0.05, 0.18])
            mode.append(z)
    
    return mode

# %%
# Adjusted modes of transport for range of age groups
mode_adj = mot(age)

drivers = mode_adj.count('private vehicle')
passengers = mode_adj.count('public transport')
cyclists = mode_adj.count('cycle')
walkers = mode_adj.count('walk')

print(drivers, passengers, cyclists, walkers)

# Output count list as 'c'.
c = [drivers] + [passengers] + [cyclists] + [walkers]

# Pie chart of randomly generated split between modes of travel. 
plt.pie(c, labels=m, explode = (0.1, 0.1, 0.1, 0.1), shadow=True, autopct='%1.1f%%')
plt.title("Modes of Travel - Randomly Generated")
plt.show()
# Out:
# 142 29 13 16

# %% [markdown]
# ### Generate Journey Distances for Various 'Modes of Travel'

# %%
# Journey distances for private vehicles
d_pv = np.random.normal(loc=13.7, scale=4, size=drivers)

# Round distances to nearest km
jd_pv = np.round(d_pv, 0)

# Output distances & distribution plot
print('Private Vehicle Distances = ', jd_pv)
sns.distplot(jd_pv, bins=10, kde=False)
plt.title("Distribution Plot for Private Vehicle Distances")
plt.show()
# Out:
# Private Vehicle Distances =  [10. 13. 15.  4. 14. 15. 19. 14. 11.  6. 13. 13. 13. 14. 15. 18. 14.  9.
#   8. 17. 12. 14. 16. 15. 13. 20. 10. 11.  9. 16. 20. 23. 14. 14.  9. 12.
#  13.  8.  8. 12. 11. 14. 18.  9.  9. 15. 13. 18. 17. 23. 19.  6. 12. 15.
#   7. 13. 10. 15.  6. 17. 12. 12. 12. 15.  9. 15. 11. 16. 14. 20. 12. 18.
#  15. 21. 12. 17. 10. 12. 11. 15. 10. 13. 15. 10. 17. 13. 21. 16. 19. 13.
#  15. 16. 16. 10. 15. 19. 18.  9. 16. 13. 18. 11.  7. 19. 13. 14. 14. 13.
#   6. 19. 11. 14. 17. 14. 12. 14.  9. 12. 18. 18.  9. 17. 15. 13. 14. 10.
#  12. 15. 27. 14. 13. 14. 17. 14. 17. 13. 15. 17. 14. 11.  8. 14.]

# %%
# Journey distances for public transport
d_pt = np.random.normal(loc=13.7, scale=3, size=passengers)

# Round distances to nearest km
jd_pt = np.round(d_pt, 0)

# Output distances & distribution plot
print('Public Transport Distances = ', jd_pt)
sns.distplot(jd_pt, bins=10, kde=False)
plt.title("Distribution Plot for Public Transport Distances")
plt.show()
# Out:
# Public Transport Distances =  [14. 14. 18. 16.  9. 17. 18. 14. 15. 17.  7. 17. 12. 11. 12. 10. 15. 16.
#  10. 13. 10. 11. 13. 18. 12. 12. 14. 10. 14.]

# %%
# Journey distances for cyclists
d_cyc = np.random.triangular(left=2, mode=13, right=14, size=cyclists)

# Round distances to nearest km
jd_cyc = np.round(d_cyc, 0)

# Output distances & distribution plot
print('Cycling Distances = ', jd_cyc)
sns.distplot(d_cyc, bins=10, kde=False)
plt.title("Distribution Plot for Cycling Distances")
plt.show()
# Out:
# Cycling Distances =  [13.  7.  6.  7.  7. 11. 12.  7. 10.  8.  6.  8.  9.]

# %%
# Journey distances for walking commuters
d_w = np.random.triangular(left=0.5, mode=5, right=5.5, size=walkers)

# Round distances to nearest km
jd_w = np.round(d_w, 0)

# Output distances & distribution plot
print('Walking Distances = ', jd_w)
sns.distplot(d_w, bins=10, kde=False)
plt.title("Distribution Plot for Walking Distances")
plt.show()
# Out:
# Walking Distances =  [4. 5. 5. 5. 5. 4. 1. 2. 4. 4. 5. 4. 5. 5. 4. 4.]

# %% [markdown]
# ### Generate Journey Times for Various 'Modes of Travel'

# %%
# Journey times for private vehicles

# account for variance in private vehicles speed by randomly adjusting speed by +/- 5km/hr
jt_pv = []
for i, j in enumerate(jd_pv):
    time_calc = round((j / (30 + np.random.randint(-5, 6))) * 60, 0)
    jt_pv.append(time_calc)
    
# Output distance vs time scatter plot
sns.scatterplot(jt_pv, jd_pv)
plt.title("Private Vehicle - Travel Time vs Travel Distance")
plt.show()

# %%
# Journey times for public transport

# account for variance in cycling speed by randomly adjusting speed by +/- 5km/hr
jt_pt = []
for i, j in enumerate(jd_pt):
    time_calc = round((j / (30 + np.random.randint(-5, 6))) * 60, 0)
    jt_pt.append(time_calc)
    
# Output distance vs time scatter plot
sns.scatterplot(jt_pt, jd_pt)
plt.title("Public Transport - Travel Time vs Travel Distance")
plt.show()

# %%
# Journey times for cycling

# account for variance in cycling speed by randomly adjusting speed by +/- 5km/hr
jt_cyc = []
for i, j in enumerate(jd_cyc):
    time_calc = round((j / (20 + np.random.randint(-5, 6))) * 60, 0)
    jt_cyc.append(time_calc)
    
# Output distance vs time scatter plot
sns.scatterplot(jt_cyc, jd_cyc)
plt.title("Cycling - Time vs Distance")
plt.show()

# %%
# Journey times for walking

# account for variance in walking speed by randomly adjusting speed by +/- 1km/hr
jt_w = []
for i, j in enumerate(jd_w):
    time_calc = round((j / (5 + np.random.randint(-1, 2))) * 60, 0)
    jt_w.append(time_calc)
    
# Output distance vs time scatter plot
sns.scatterplot(jt_w, jd_w)
plt.title("Walking - Time vs Distance")
plt.show()

# %% [markdown]
# ### Complie Data into Pandas DataFrame

# %%
# Create Pandas Data Frame
data = {'Gender': gender, 'Age': age, 'Mode of Travel': mode_adj, 'Journey Distance (km)': None, 'Journey Time (mins)': None}
df = pd.DataFrame(data)
df
# Out:
#      Gender  Age    Mode of Travel Journey Distance (km) Journey Time (mins)
# 0    Female   21             cycle                  None                None
# 1    Female   22              walk                  None                None
# 2    Female   25   private vehicle                  None                None
# 3    Female   34   private vehicle                  None                None
# 4      Male   35  public transport                  None                None
# 5    Female   43   private vehicle                  None                None
# 6      Male   47   private vehicle                  None                None
# 7    Female   33   private vehicle                  None                None
# 8      Male   25   private vehicle                  None                None
# 9    Female   49  public transport                  None                None
# 10   Female   20  public transport                  None                None
# 11     Male   63   private vehicle                  None                None
# 12     Male   51   private vehicle                  None                None
# 13   Female   60   private vehicle                  None                None
# 14     Male   28   private vehicle                  None                None
# 15   Female   50  public transport                  None                None
# 16   Female   50   private vehicle                  None                None
# 17     Male   59   private vehicle                  None                None
# 18   Female   41              walk                  None                None
# 19     Male   25   private vehicle                  None                None
# 20     Male   39   private vehicle                  None                None
# 21   Female   30   private vehicle                  None                None
# 22     Male   64              walk                  None                None
# 23     Male   54   private vehicle                  None                None
# 24   Female   52   private vehicle                  None                None
# 25   Female   51  public transport                  None                None
# 26   Female   62             cycle                  None                None
# 27     Male   33   private vehicle                  None                None
# 28     Male   28   private vehicle                  None                None
# 29     Male   51   private vehicle                  None                None
# 30     Male   19  public transport                  None                None
# 31     Male   40  public transport                  None                None
# 32   Female   32   private vehicle                  None                None
# 33   Female   29   private vehicle                  None                None
# 34     Male   26   private vehicle                  None                None
# 35   Female   48   private vehicle                  None                None
# 36   Female   42   private vehicle                  None                None
# 37   Female   23  public transport                  None                None
# 38     Male   41              walk                  None                None
# 39     Male   37   private vehicle                  None                None
# 40   Female   28   private vehicle                  None                None
# 41   Female   54   private vehicle                  None                None
# 42     Male   35   private vehicle                  None                None
# 43   Female   53  public transport                  None                None
# 44     Male   55  public transport                  None                None
# 45   Female   59             cycle                  None                None
# 46     Male   25   private vehicle                  None                None
# 47     Male   39             cycle                  None                None
# 48   Female   30   private vehicle                  None                None
# 49   Female   39   private vehicle                  None                None
# 50   Female   30   private vehicle                  None                None
df.loc[df['Mode of Travel'] == 'private vehicle', 'Journey Distance (km)'] = jd_pv
df.loc[df['Mode of Travel'] == 'private vehicle', 'Journey Time (mins)'] = jt_pv

df.loc[df['Mode of Travel'] == 'public transport', 'Journey Distance (km)'] = jd_pt
df.loc[df['Mode of Travel'] == 'public transport', 'Journey Time (mins)'] = jt_pt

# %% [markdown]
# ### Adjusting Dataset

# %%
#df.loc[(df['Age'] > 54) & (df['Mode of Travel'] == 'walk')]
#df.loc[(df['Age'] > 59) & (df['Mode of Travel'] == 'cycle')]
#df.loc[(df['Age'] < 24) & (df['Mode of Travel'] == 'private vehicle')]

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df.sort_values(by='Age', ascending=True)
# Out:
#      Gender  Age    Mode of Travel Journey Distance (km) Journey Time (mins)
# 128    Male   18              walk                     4                  60
# 140    Male   18             cycle                     8                  25
# 164    Male   18             cycle                     6                  18
# 79   Female   19              walk                     4                  40
# 93     Male   19   private vehicle                     9                  19
# 30     Male   19  public transport                    17                  29
# 178    Male   19             cycle                     9                  22
# 51     Male   20   private vehicle                    14                  31
# 133  Female   20              walk                     5                  60
# 83   Female   20   private vehicle                    10                  17
# 145  Female   20   private vehicle                    18                  40
# 10   Female   20  public transport                    18                  35
# 0    Female   21             cycle                    13                  32
# 1    Female   22              walk                     4                  60
# 124  Female   22   private vehicle                    16                  33
# 173    Male   22   private vehicle                    13                  28
# 165    Male   22  public transport                    12                  28
# 143    Male   23   private vehicle                    16                  29
# 86     Male   23  public transport                    15                  35
# 102  Female   23   private vehicle                    15                  29
# 112    Male   23             cycle                     7                  19
# 37   Female   23  public transport                    14                  34
# 192    Male   23   private vehicle                    15                  26
# 131  Female   24   private vehicle                    15                  28
# 130  Female   24              walk                     4                  48
# 126    Male   24             cycle                    10                  27
# 113  Female   24              walk                     2                  24
# 85     Male   24   private vehicle                     6                  11
# 152    Male   24   private vehicle                    13                  24
# 46     Male   25   private vehicle                    16                  27
# 2    Female   25   private vehicle                    10                  20
# 186  Female   25   private vehicle                    14                  25
# 8      Male   25   private vehicle                    15                  36
# 19     Male   25   private vehicle                    13                  25
# 118  Female   26  public transport                    13                  24
# 34     Male   26   private vehicle                    16                  29
# 61   Female   26   private vehicle                    11                  19
# 137    Male   26   private vehicle                    15                  36
# 97   Female   26   private vehicle                    16                  27
# 123    Male   27   private vehicle                    21                  42
# 59   Female   27             cycle                     7                  25
# 105    Male   27   private vehicle                    17                  35
# 58     Male   27   private vehicle                     8                  14
# 40   Female   28   private vehicle                    10                  18
# 181  Female   28   private vehicle                    14                  28
# 28     Male   28   private vehicle                     8                  14
# 66   Female   28   private vehicle                     9                  18
# 14     Male   28   private vehicle                     6                  11
# 188  Female   28   private vehicle                    17                  31
# 180  Female   29   private vehicle                    27                  46
# 33   Female   29   private vehicle                    14                  34
# 156  Female   29   private vehicle                    11                  21
# 48   Female   30   private vehicle                    20                  43
# 50   Female   30   private vehicle                    14                  24
# 21   Female   30   private vehicle                    15                  27
# 195    Male   30   private vehicle                    11                  22
# 177  Female   31   private vehicle                    12                  27
# 157    Male   31   private vehicle                    14                  32
# 122  Female   31   private vehicle                    13                  25
# 32   Female   32   private vehicle                    12                  22
# 147    Male   32   private vehicle                     7                  14
# 175    Male   33   private vehicle                    10                  23
# 7    Female   33   private vehicle                    14                  28
# 89     Male   33   private vehicle                    12                  26
# 139  Female   33  public transport                    13                  24
# 27     Male   33   private vehicle                     9                  21
# 69   Female   33  public transport                    11                  21
# 189    Male   34  public transport                    10                  17
# 121  Female   34   private vehicle                    17                  31
# 3    Female   34   private vehicle                    13                  28
# 108    Male   34             cycle                    11                  30
# 100  Female   35   private vehicle                    12                  23
# 42     Male   35   private vehicle                     9                  20
# 194    Male   35   private vehicle                    14                  29
# 158    Male   35   private vehicle                    17                  38
# 87   Female   35   private vehicle                    17                  35
# 4      Male   35  public transport                    14                  29
# 111  Female   36   private vehicle                    11                  21
# 171    Male   36   private vehicle                    17                  32
# 199    Male   36   private vehicle                    14                  26
# 68     Male   36  public transport                    12                  25
# 64     Male   37  public transport                    17                  33
# 39     Male   37   private vehicle                    20                  39
# 56     Male   38   private vehicle                    13                  31
# 67   Female   38   private vehicle                    15                  35
# 49   Female   39   private vehicle                    23                  51
# 185    Male   39  public transport                    12                  21
# 172  Female   39   private vehicle                    15                  27
# 167  Female   39   private vehicle                    12                  23
# 20     Male   39   private vehicle                    14                  30
# 161    Male   39              walk                     5                  50
# 47     Male   39             cycle                     7                  23
# 31     Male   40  public transport                    18                  36
# 149  Female   40   private vehicle                    13                  25
# 82     Male   40   private vehicle                    13                  22
# 78   Female   40   private vehicle                    15                  27
# 65   Female   40   private vehicle                     9                  19
# 148  Female   40   private vehicle                    19                  37
# 98   Female   40   private vehicle                    14                  31
# 103    Male   40   private vehicle                    21                  39
# 38     Male   41              walk                     5                  60
# 18   Female   41              walk                     5                  75
# 109  Female   41   private vehicle                    12                  29
# 53   Female   41  public transport                     7                  13
# 72     Male   41   private vehicle                    17                  34
# 70     Male   41   private vehicle                    13                  30
# 76     Male   41   private vehicle                     6                  13
# 169    Male   42   private vehicle                    18                  31
# 36   Female   42   private vehicle                    13                  24
# 94     Male   42   private vehicle                    15                  33
# 110  Female   42             cycle                    12                  33
# 62     Male   42   private vehicle                    14                  32
# 163    Male   43  public transport                    18                  40
# 176  Female   43             cycle                     8                  19
# 5    Female   43   private vehicle                    15                  28
# 153    Male   43   private vehicle                     6                  11
# 198  Female   43   private vehicle                     8                  14
# 107  Female   43  public transport                    10                  19
# 174    Male   43   private vehicle                    14                  26
# 90   Female   44              walk                     1                  12
# 142  Female   44   private vehicle                     9                  22
# 134    Male   44              walk                     4                  60
# 101  Female   44   private vehicle                    18                  42
# 80     Male   45   private vehicle                     7                  14
# 182  Female   45   private vehicle                    13                  30
# 183    Male   45   private vehicle                    14                  29
# 88   Female   45   private vehicle                    12                  23
# 60     Male   45   private vehicle                    12                  24
# 127  Female   46   private vehicle                    13                  30
# 136    Male   46   private vehicle                    10                  17
# 116  Female   47   private vehicle                    13                  26
# 141  Female   47   private vehicle                    18                  34
# 6      Male   47   private vehicle                     4                  10
# 104  Female   48   private vehicle                    12                  24
# 52     Male   48   private vehicle                     9                  18
# 92     Male   48   private vehicle                    15                  30
# 35   Female   48   private vehicle                    15                  30
# 138  Female   48   private vehicle                    19                  41
# 151    Male   49   private vehicle                    14                  31
# 155    Male   49              walk                     5                  75
# 57     Male   49   private vehicle                     8                  14
# 114    Male   49   private vehicle                    15                  26
# 9    Female   49  public transport                    14                  26
# 55     Male   50   private vehicle                    12                  22
# 16   Female   50   private vehicle                    13                  26
# 15   Female   50  public transport                    16                  38
# 117    Male   50   private vehicle                    15                  30
# 25   Female   51  public transport                     9                  16
# 129    Male   51  public transport                    11                  22
# 120    Male   51  public transport                    10                  21
# 184    Male   51   private vehicle                    17                  35
# 29     Male   51   private vehicle                    17                  41
# 12     Male   51   private vehicle                    14                  30
# 71     Male   52   private vehicle                    18                  35
# 193  Female   52   private vehicle                    17                  36
# 24   Female   52   private vehicle                    14                  25
# 43   Female   53  public transport                    15                  36
# 84     Male   53   private vehicle                    15                  26
# 115  Female   53   private vehicle                    10                  24
# 132    Male   53   private vehicle                    16                  28
# 95   Female   53  public transport                    16                  37
# 170    Male   54   private vehicle                     9                  20
# 41   Female   54   private vehicle                    11                  22
# 23     Male   54   private vehicle                    18                  42
# 44     Male   55  public transport                    17                  30
# 81   Female   56  public transport                    10                  21
# 190    Male   56   private vehicle                    13                  22
# 54   Female   56              walk                     5                  50
# 159    Male   57   private vehicle                    14                  25
# 197  Female   57              walk                     4                  48
# 146  Female   58   private vehicle                    11                  24
# 125  Female   58   private vehicle                    19                  44
# 74     Male   58   private vehicle                    19                  38
# 119  Female   59   private vehicle                    10                  22
# 17     Male   59   private vehicle                    13                  24
# 45   Female   59             cycle                     6                  19
# 168    Male   59   private vehicle                    18                  37
# 135  Female   59   private vehicle                    16                  28
# 166  Female   59   private vehicle                     9                  18
# 179    Male   60   private vehicle                    15                  32
# 13   Female   60   private vehicle                    11                  19
# 63   Female   61   private vehicle                    18                  37
# 162    Male   61   private vehicle                    14                  28
# 73     Male   61   private vehicle                    23                  46
# 75   Female   62  public transport                    12                  21
# 77     Male   62   private vehicle                    12                  23
# 150    Male   62   private vehicle                    14                  34
# 96     Male   62   private vehicle                    11                  20
# 26   Female   62             cycle                     7                  18
# 187  Female   63  public transport                    14                  25
# 11     Male   63   private vehicle                    19                  35
# 106  Female   63   private vehicle                    10                  23
# 154    Male   63   private vehicle                    19                  35
# 91   Female   63   private vehicle                    12                  21
# 191    Male   64              walk                     4                  40
# 22     Male   64              walk                     5                  50
# 144  Female   64   private vehicle                    13                  30
# 160  Female   64   private vehicle                    12                  26
# 196    Male   64  public transport                    14                  31
# 99   Female   64   private vehicle                    20                  43

# %%
sns.scatterplot(data=df, x='Journey Distance (km)', y='Age', hue='Mode of Travel')

# %%
sns.pairplot(data=df, hue="Mode of Travel")
plt.show()

# %% [markdown]
# ## Reference:
#
# https://aran.library.nuigalway.ie/bitstream/handle/10379/14605/manuscript.v8.pdf?sequence=1&isAllowed=y
# https://www.galwaycity.ie/uploads/downloads/news_items/Traffic-Transport/GTS/GTS%20Appendix%20A%20Transport%20Demand.pdf

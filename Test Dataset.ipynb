# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %% [markdown]
# ### Commuter's Gender & Age

# %%
g = ['Male', 'Female']
gender = np.random.choice(g, size=100, p=(0.489, 0.511))

age = np.random.randint(low=18, high=65, size=100)

data = {'Gender':gender, 'Age':age, 'Mode of Travel':mode}

# %% [markdown]
# ### Commuter's Mode of Travel

# %%
# list of modes of travel.
m = ['private vehicle', 'public transport', 'cycle', 'walk']

# percentage split between modes of travel - 'private vehicle', 'public transport', 'cycle', 'walk'.
percentage = [0.62, 0.09, 0.11, 0.18]

# Generate 100 random data points for the different modes of travel, probability as per percentage split.
mode = np.random.choice(m, size=100, p=(percentage))

# Change NumPy Array to List to allow for counting of random modes of travel generated.
mode_list = mode.tolist()

# Count number of commuters using each mode of travel.
drivers = mode_list.count('private vehicle')
passengers = mode_list.count('public transport')
cyclists = mode_list.count('cycle')
walkers = mode_list.count('walk')

# Output count list as 'c'.
c = [drivers] + [passengers] + [cyclists] + [walkers]

# Pie chart of percentage split between modes of travel.    
plt.pie(percentage, labels=m, explode = (0.1, 0.1, 0.1, 0.1), shadow=True, autopct='%1.1f%%')
plt.title("Modes of Travel - Percentage Split")
plt.show()

# Pie chart of randomly generated split between modes of travel. 
plt.pie(c, labels=m, explode = (0.1, 0.1, 0.1, 0.1), shadow=True, autopct='%1.1f%%')
plt.title("Modes of Travel - Randomly Generated")
plt.show()

# %% [markdown]
# ### Generate Journey Distances for Various 'Modes of Travel'

# %%
# Journey distances for walking commuters
d_w = np.random.triangular(left=0, mode=5, right=6, size=walkers)

# Round distances to nearest km
jd_w = np.round(d_w, 0)

# Output distances & distribution plot
print('Walking Distances = ', jd_w)
sns.distplot(d_w, kde=False)
plt.title("Distribution Plot for Walking Distances")
plt.show()
# Out:
# Walking Distances =  [3. 3. 3. 1. 4. 4. 5. 4. 2. 5. 4. 4. 6.]

# %%
# Journey distances for cyclists
d_cyc = np.random.triangular(left=2, mode=13, right=14, size=cyclists)

# Round distances to nearest km
jd_cyc = np.round(d_cyc, 0)

# Output distances & distribution plot
print('Cycling Distances = ', jd_cyc)
sns.distplot(d_cyc, kde=False)
plt.title("Distribution Plot for Cycling Distances")
plt.show()
# Out:
# Cycling Distances =  [12.  9. 12. 12. 12.  7.  9. 10. 11. 11. 10. 12.  9.]

# %%
# Journey distances for public transport
d_pt = np.random.normal(loc=13.7, scale=4, size=passengers)

# Round distances to nearest km
jd_pt = np.round(d_pt, 0)

# Output distances & distribution plot
print('Public Transport Distances = ', jd_pt)
sns.distplot(jd_pt, bins=passengers, kde=False)
plt.title("Distribution Plot for Public Transport Distances")
plt.show()
# Out:
# Public Transport Distances =  [11.  9. 14. 14. 13. 12. 19. 10.]

# %%
# Journey distances for private vehicles
d_pv = np.random.normal(loc=13.7, scale=4, size=drivers)

# Round distances to nearest km
jd_pv = np.round(d_pv, 0)

# Output distances & distribution plot
print('Private Vehicle Distances = ', jd_pv)
sns.distplot(jd_pv, bins=10, kde=False)
plt.title("Distribution Plot for Private Vehicle Distances")
plt.show()
# Out:
# Private Vehicle Distances =  [12. 15. 10. 19. 18. 15. 12. 16. 15. 14. 18. 11. 21. 18. 15. 10. 10. 14.
#  12. 23. 14. 21. 15.  9.  5.  8. 13. 15. 11. 10. 15. 11. 10. 16. 17. 15.
#  23. 19. 14. 12. 12. 12. 15. 20. 13. 15. 13.  9. 11. 16. 13. 12. 16. 15.
#  15.  9. 14. 17. 13.  8. 16.  6. 22. 17. 21. 17.]

# %% [markdown]
# ## Generate Journey Times for Various 'Modes of Travel'

# %%
# Journey times for walking
jt_w = []
for i in range(0, walkers):
    r = random.randint(-1, 1)
    jt_w = (jd_w / (5 + r)   * 60)

print("Walking Times =", jt_w)
# Out:
# Walking Times = [45. 45. 45. 15. 60. 60. 75. 60. 30. 75. 60. 60. 90.]

# %%
# Journey time for cycling
# adding in an random value between 0 & 10, so data doesn't appear too linear
jt_cyc = ((jd_cyc / 20) * 60) + random.randint(0, 10)
jt_cyc
# Out:
# array([29., 32., 38., 41., 32., 38., 38., 23., 50., 32., 35., 35.])

# %%
# Journey time for public transport
jt_pt = (jd_pt / 30) * 60

# %%
# Journey time for private vehicles
jt_pv = np.round((jd_pv / 30) * 60, 0) + random.randint(0, 10)

# %%
df = pd.DataFrame(data, columns=['Gender', 'Age', 'Mode of Travel', 'Journey Distance', 'Journey Time'])

# %%
pv = df[df['Mode of Travel'] == 'private vehicle']

# %%
pt = df[df['Mode of Travel'] == 'public transport']

# %%
cyc = df[df['Mode of Travel'] == 'cycle']

# %%
w = df[df['Mode of Travel'] == 'walk']

# %%
df[df['Mode of Travel'] == 'walk']
# Out:
#     Gender  Age Mode of Transport Journey Distance Journey Time
# 18  Female   32              walk                3           36
# 22    Male   46              walk                4           48
# 34    Male   37              walk                2           24
# 41  Female   19              walk                2           24
# 43  Female   47              walk                6           72
# 51    Male   53              walk                3           36
# 62    Male   34              walk                4           48
# 74  Female   35              walk                5           60
# 79  Female   33              walk                5           60
# 80  Female   20              walk                3           36
# 82  Female   49              walk                4           48
# 83  Female   41              walk                4           48
# 84  Female   32              walk                3           36
# 89  Female   30              walk                4           48

# %%
df.loc[df['Mode of Travel'] == 'walk', 'Journey Distance'] = jd_w
df.loc[df['Mode of Travel'] == 'walk', 'Journey Time'] = jt_w

df.loc[df['Mode of Travel'] == 'cycle', 'Journey Distance'] = jd_cyc
df.loc[df['Mode of Travel'] == 'cycle', 'Journey Time'] = jt_cyc

df.loc[df['Mode of Travel'] == 'private vehicle', 'Journey Distance'] = jd_pv
df.loc[df['Mode of Travel'] == 'private vehicle', 'Journey Time'] = jt_pv

df.loc[df['Mode of Travel'] == 'public transport', 'Journey Distance'] = jd_pt
df.loc[df['Mode of Travel'] == 'public transport', 'Journey Time'] = jt_pt

# %%
sns.scatterplot(x=jd_w, y=jt_w)
sns.scatterplot(x=jd_cyc, y=jt_cyc)
sns.scatterplot(x=jd_pv, y=jt_pv)
sns.scatterplot(x=jd_pt, y=jt_pt)

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df
# Out:
#     Gender  Age Mode of Transport Journey Distance Journey Time
# 0     Male   59   private vehicle                9           18
# 1     Male   27              walk                4           49
# 2   Female   53   private vehicle               14           28
# 3     Male   29   private vehicle               19           38
# 4   Female   47   private vehicle               16           32
# 5   Female   59             cycle               13           43
# 6   Female   43              walk                1           13
# 7   Female   25              walk                4           49
# 8   Female   56   private vehicle               19           38
# 9   Female   21              walk                4           49
# 10    Male   46              walk                3           37
# 11  Female   35   private vehicle               12           24
# 12  Female   18   private vehicle               20           40
# 13  Female   36   private vehicle               13           26
# ...

# %%
mode_count = [len(pv), len(pt), len(cyc), len(w)]

plt.pie(mode_count, labels=m, explode = (0.1, 0.1, 0.1, 0.1), shadow=True, autopct='%1.1f%%')
plt.title("Pie Chart of Modes of Travel")
plt.show()

# %%
df['Gender'] == 'Male' & df['Model of Travel'] == 'private vehicle'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Model of Transport'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-5aee0c9357e7> in <module>
# ...

# %%
sns.catplot(data=df, kind="bar", x="Mode of Travel", y='Age', hue="Gender")

# %%
sns.pairplot(data=df, hue="Gender")

# %% [markdown]
# ## Reference:
#
# https://aran.library.nuigalway.ie/bitstream/handle/10379/14605/manuscript.v8.pdf?sequence=1&isAllowed=y
# https://www.galwaycity.ie/uploads/downloads/news_items/Traffic-Transport/GTS/GTS%20Appendix%20A%20Transport%20Demand.pdf
